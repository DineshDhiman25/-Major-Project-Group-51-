# %%
import pandas as pd
df = pd.read_csv("/Users/dineshdhiman/Code/Major_Grp51/Dinesh/Annotation/Csv/hrv_train_venezuela.csv")

# %%
df.Label.value_counts()
# Out:
# Label
# No     2287
# Yes     213
# Name: count, dtype: int64
